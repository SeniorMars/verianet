# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import Sequence
from tensorflow.keras.layers import Dense, Input

from tensorflow.keras.datasets import mnist

# %%
#loading dataset
(x_train, y_train ), (x_test, y_test) = mnist.load_data()

# Resize training and test images to 7x7
x_train = tf.image.resize(x_train[..., tf.newaxis], [7, 7]).numpy()
x_test = tf.image.resize(x_test[..., tf.newaxis], [7, 7]).numpy()

# Remove the channel dimension if needed
#x_train_resized = x_train_resized.squeeze()
#x_test_resized = x_test_resized.squeeze()

# Normalization of x_train and y_train
x_train = x_train / 255
x_test = x_test /255

# %%
# to see the images present in x_train and mnist dataset
for i in range(5):
    plt.matshow(x_train[i])
    print("Number = ", y_train[i])
    plt.show()
# Out:
# Number =  5
# Number =  0
# Number =  4
# Number =  1
# Number =  9

# %%
model = keras.Sequential(
    [keras.layers.Flatten(input_shape = (7, 7)),
    Dense(3, activation = 'gelu'),
    Dense(3, activation = 'gelu'),
    Dense(10, activation = 'softmax')]

)
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)                  │ (None, 49)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             150 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │              12 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │              40 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 202 (808.00 B)
#  Trainable params: 202 (808.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss= 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 20)
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Accuracy : {test_accuracy*100} % \nTest Loss : {test_loss}')
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.3717 - loss: 1.7629 - val_accuracy: 0.4695 - val_loss: 1.4407
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5097 - loss: 1.3359 - val_accuracy: 0.5458 - val_loss: 1.2362
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5634 - loss: 1.2114 - val_accuracy: 0.5886 - val_loss: 1.1561
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5899 - loss: 1.1555 - val_accuracy: 0.6062 - val_loss: 1.1134
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6028 - loss: 1.1233 - val_accuracy: 0.6181 - val_loss: 1.0847
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6141 - loss: 1.1006 - val_accuracy: 0.6248 - val_loss: 1.0649
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6224 - loss: 1.0833 - val_accuracy: 0.6334 - val_loss: 1.0555
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6283 - loss: 1.0701 - val_accuracy: 0.6397 - val_loss: 1.0368
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6319 - loss: 1.0591 - val_accuracy: 0.6457 - val_loss: 1.0296
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6365 - loss: 1.0494 - val_accuracy: 0.6493 - val_loss: 1.0211
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6392 - loss: 1.0417 - val_accuracy: 0.6471 - val_loss: 1.0149
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6421 - loss: 1.0341 - val_accuracy: 0.6513 - val_loss: 1.0071
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6439 - loss: 1.0272 - val_accuracy: 0.6537 - val_loss: 1.0023
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6453 - loss: 1.0206 - val_accuracy: 0.6602 - val_loss: 0.9947
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6489 - loss: 1.0140 - val_accuracy: 0.6580 - val_loss: 0.9887
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6492 - loss: 1.0073 - val_accuracy: 0.6651 - val_loss: 0.9804
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6522 - loss: 1.0010 - val_accuracy: 0.6643 - val_loss: 0.9777
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6547 - loss: 0.9955 - val_accuracy: 0.6679 - val_loss: 0.9695
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6554 - loss: 0.9900 - val_accuracy: 0.6693 - val_loss: 0.9648
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6577 - loss: 0.9853 - val_accuracy: 0.6702 - val_loss: 0.9603
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6702 - loss: 0.9603
# Test Accuracy : 67.0199990272522 %
# Test Loss : 0.9602965712547302

# %%
weights_and_biases = model.get_weights()

# %%
weights = []
biases = []
for i, arr in enumerate(weights_and_biases):
    if i % 2 == 0:
        weights.append(arr)
    else:
        biases.append(arr)
print(weights)
print(biases)
# Out:
# [array([[-0.2539715 ,  0.22023244, -0.28111094],
#        [-1.4106457 ,  1.2950541 , -1.4850706 ],
#        [-2.6086884 ,  0.8649939 , -2.9234874 ],
#        [-2.4531713 ,  0.46880594, -3.7321732 ],
#        [-2.3112051 ,  2.4903524 , -4.003599  ],
#        [-2.1290202 ,  2.4457636 , -5.3336363 ],
#        [-1.1735591 ,  0.44198266, -0.3400019 ],
#        [-0.14291608, -0.06370132, -1.0667809 ],
#        [ 0.0545512 ,  0.09644409,  0.38170806],
#        [-0.06369825,  0.27245477,  0.43068007],
#        [-0.0689204 ,  0.35682797,  0.48513654],
#        [ 0.03716166,  0.49863818,  0.32821575],
#        [ 0.3241773 ,  0.37406614,  0.21851723],
#        [ 2.2258458 ,  4.8359504 ,  2.1044228 ],
#        [ 0.39876473, -0.07548197, -1.4482992 ],
#        [ 0.01977086, -0.7195892 , -0.1712975 ],
#        [ 0.41356927,  0.5008218 , -0.06068341],
#        [ 0.25127208,  0.05422733,  0.06837082],
#        [ 0.20540936, -0.14344996,  0.00617498],
#        [ 0.29015568,  0.6284701 ,  0.16257665],
#        [ 1.8692209 ,  2.9466715 ,  2.790375  ],
#        [ 0.94815844, -0.61877996, -2.4099953 ],
#        [ 0.90409243,  2.2674384 , -0.10463363],
#        [ 0.44796464,  2.2109723 ,  0.24949908],
#        [-0.02151129, -0.7558042 ,  0.32933846],
#        [ 0.19501731, -0.08108606, -0.263234  ],
#        [ 0.07254522,  0.89880073, -0.39839336],
#        [-0.94986165,  0.5000994 , -0.16375463],
#        [-0.1795875 ,  0.89919436,  1.8845638 ],
#        [-0.36016452,  0.7344169 ,  0.321871  ],
#        [-0.35284853,  0.1376169 , -0.24416222],
#        [-0.3858549 , -1.0293833 , -0.39474836],
#        [-0.07272661,  0.41271994, -0.04872841],
#        [-0.26803932,  0.530357  ,  0.28095326],
#        [-2.5450296 ,  0.47072184,  0.02630386],
#        [-0.43003452,  3.0257504 ,  2.115382  ],
#        [-0.42719457,  0.5175245 ,  0.825324  ],
#        [-0.17945972,  0.37879997,  0.39877126],
#        [-0.02054725,  0.5308999 ,  0.12190043],
#        [-0.08350429,  0.31094584,  0.24734272],
#        [-0.3897309 ,  0.01513488,  0.2644411 ],
#        [-1.9425333 ,  0.63439995,  0.04678583],
#        [-0.44601685, -0.10102284,  1.5250993 ],
#        [ 0.66290146, -1.467709  , -0.7011592 ],
#        [ 1.5749754 , -0.2779314 ,  0.52905583],
#        [ 1.4999317 , -0.391296  ,  0.60897523],
#        [ 1.8797728 , -0.02663187,  0.7366189 ],
#        [ 1.983488  , -1.1488619 ,  1.1773294 ],
#        [ 0.11440858, -0.19243534, -0.5031004 ]], dtype=float32), array([[-0.17272657,  2.4266944 , -1.0926687 ],
#        [ 1.1665508 ,  1.0711663 ,  2.0882108 ],
#        [-2.0627623 , -0.6133794 ,  0.58404994]], dtype=float32), array([[ 0.1645136 , -1.839937  ,  0.1893904 , -2.5614388 ,  0.946168  ,
#         -1.7520344 ,  1.3429482 ,  1.3727399 , -1.6478854 ,  0.06355198],
#        [-0.49841365, -1.2932202 , -2.4444313 ,  0.06564598,  0.32666233,
#          0.4602883 , -1.4694577 ,  1.0570847 ,  0.09343629,  0.9267551 ],
#        [ 0.64370126, -0.7377813 ,  0.8834456 ,  0.4728069 , -0.94773036,
#          0.20701148,  0.18823937, -2.6251085 ,  0.10881957, -1.2723173 ]],
#       dtype=float32)]
# [array([1.1015279 , 1.4343119 , 0.48474932], dtype=float32), array([ 1.2442513, -0.8914768,  0.3933975], dtype=float32), array([-5.8320017 ,  6.305123  ,  1.6840422 ,  0.31187585, -1.0098728 ,
#        -1.1274781 , -0.81853694, -0.0096055 ,  1.2583326 , -0.2836282 ],
#       dtype=float32)]
